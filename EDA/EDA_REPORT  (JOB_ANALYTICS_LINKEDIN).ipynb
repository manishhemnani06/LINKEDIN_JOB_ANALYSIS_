# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# # 1. Basic Exploration

# %% [markdown]
# ## 1.1 Data Sample

# %%
df=pd.read_csv(r"..\EXCEL\final_data.csv",encoding='cp1252')

# %%
df.sample(5)
# Out:
#                          Name    Class  \
# 238               LTIMindtree  Class 3
# 235               LTIMindtree  Class 3
# 430  IDESLABS PRIVATE LIMITED  Class 2
# 477  IDESLABS PRIVATE LIMITED  Class 2
# 528  IDESLABS PRIVATE LIMITED  Class 2
#
#                                            Designation      Location  \
# 238  Oracle EPBCS (Enterprise Planning and Budgetin...   Maharashtra
# 235             LTIMindtree Hiring SAP Project Manager     Karnataka
# 430                                      PHP Developer    Tamil Nadu
# 477                               Sr. Security Analyst   Maharashtra
# 528                          Associate Tech Specialist     Telangana
#
#      Total_applicants  LinkedIn_Followers       Level        Involvement  \
# 238                 3              270280  Full-time         Entry level
# 235                 0              270280  Full-time    Mid-Senior level
# 430                10               80865  Full-time         Entry level
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Class', 'Designation', 'Location', 'Total_applicants',
#        'LinkedIn_Followers', 'Level', 'Involvement', 'Employee_count',
#        'Industry', 'PYTHON', 'C++', 'JAVA', 'HADOOP', 'SCALA', 'FLASK',
#        'PANDAS', 'SPARK', 'NUMPY', 'PHP', 'SQL', 'MYSQL', 'CSS', 'MONGODB',
#        'NLTK', 'TENSORFLOW', 'LINUX', 'RUBY', 'JAVASCRIPT', 'DJANGO', 'REACT',
#        'REACTJS', 'AI', 'UI', 'TABLEAU', 'NODEJS', 'EXCEL', 'POWER BI',
#        'SELENIUM', 'HTML', 'ML'],
#       dtype='object')

# %%
df.columns=['Company_Name', 'Class', 'Designation', 'Location', 'Total_applicants',
       'LinkedIn_Followers', 'Level', 'Involvement', 'Employee_count',
       'Industry', 'PYTHON', 'C++', 'JAVA', 'HADOOP', 'SCALA', 'FLASK',
       'PANDAS', 'SPARK', 'NUMPY', 'PHP', 'SQL', 'MYSQL', 'CSS', 'MONGODB',
       'NLTK', 'TENSORFLOW', 'LINUX', 'RUBY', 'JAVASCRIPT', 'DJANGO', 'REACT',
       'REACTJS', 'AI', 'UI', 'TABLEAU', 'NODEJS', 'EXCEL', 'POWER BI',
       'SELENIUM', 'HTML', 'ML']

# %% [markdown]
# ## 1.2 Data Shape & Size

# %%
df.shape
# Out:
# (811, 41)

# %%
df.size
# Out:
# 33251

# %% [markdown]
# ## 1.3 Data Info

# %%
df.dtypes
# Out:
# Company_Name          object
# Class                 object
# Designation           object
# Location              object
# Total_applicants       int64
# LinkedIn_Followers     int64
# Level                 object
# Involvement           object
# Employee_count         int64
# Industry              object
# PYTHON                 int64
# C++                    int64
# JAVA                   int64
# HADOOP                 int64
# SCALA                  int64
# FLASK                  int64
# PANDAS                 int64
# SPARK                  int64
# NUMPY                  int64
# PHP                    int64
# SQL                    int64
# MYSQL                  int64
# CSS                    int64
# MONGODB                int64
# NLTK                   int64
# TENSORFLOW             int64
# LINUX                  int64
# RUBY                   int64
# JAVASCRIPT             int64
# DJANGO                 int64
# REACT                  int64
# REACTJS                int64
# ...

# %%
df['LinkedIn_Followers']=df['LinkedIn_Followers'].astype('str')

# %%
df.dtypes
# Out:
# Company_Name          object
# Class                 object
# Designation           object
# Location              object
# Total_applicants       int64
# LinkedIn_Followers    object
# Level                 object
# Involvement           object
# Employee_count         int64
# Industry              object
# PYTHON                 int64
# C++                    int64
# JAVA                   int64
# HADOOP                 int64
# SCALA                  int64
# FLASK                  int64
# PANDAS                 int64
# SPARK                  int64
# NUMPY                  int64
# PHP                    int64
# SQL                    int64
# MYSQL                  int64
# CSS                    int64
# MONGODB                int64
# NLTK                   int64
# TENSORFLOW             int64
# LINUX                  int64
# RUBY                   int64
# JAVASCRIPT             int64
# DJANGO                 int64
# REACT                  int64
# REACTJS                int64
# ...

# %% [markdown]
# ## 1.4 Null Value Check

# %%
df.isnull().sum()
# Out:
# Company_Name          0
# Class                 0
# Designation           0
# Location              0
# Total_applicants      0
# LinkedIn_Followers    0
# Level                 0
# Involvement           0
# Employee_count        0
# Industry              0
# PYTHON                0
# C++                   0
# JAVA                  0
# HADOOP                0
# SCALA                 0
# FLASK                 0
# PANDAS                0
# SPARK                 0
# NUMPY                 0
# PHP                   0
# SQL                   0
# MYSQL                 0
# CSS                   0
# MONGODB               0
# NLTK                  0
# TENSORFLOW            0
# LINUX                 0
# RUBY                  0
# JAVASCRIPT            0
# DJANGO                0
# REACT                 0
# REACTJS               0
# AI                    0
# UI                    0
# TABLEAU               0
# NODEJS                0
# EXCEL                 0
# POWER BI              0
# ...

# %% [markdown]
# ## 1.5 Basic Maths Analysis

# %%
df["Total_applicants"].describe()
# Out:
# count    811.000000
# mean      23.432799
# std       35.137773
# min        0.000000
# 25%        2.000000
# 50%        8.000000
# 75%       31.000000
# max      196.000000
# Name: Total_applicants, dtype: float64

# %%
df["Employee_count"].describe()
# Out:
# count      811.000000
# mean      5177.552404
# std       4194.169581
# min        110.000000
# 25%       1200.000000
# 50%       5000.000000
# 75%      10001.000000
# max      10001.000000
# Name: Employee_count, dtype: float64

# %%
df["LinkedIn_Followers"].describe()
# Out:
# count       811
# unique       11
# top       80865
# freq        265
# Name: LinkedIn_Followers, dtype: object

# %% [markdown]
# ## 1.6  Duplicate Value Check

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 1.7  correlation in DataSet

# %%
df.corr()
# Out:
#                   Total_applicants  Employee_count    PYTHON       C++  \
# Total_applicants          1.000000        0.124307  0.090981  0.135494
# Employee_count            0.124307        1.000000  0.012093  0.025696
# PYTHON                    0.090981        0.012093  1.000000  0.469889
# C++                       0.135494        0.025696  0.469889  1.000000
# JAVA                      0.046953       -0.043989  0.328027  0.201595
# HADOOP                    0.072944        0.004157  0.493245  0.659008
# SCALA                     0.082822        0.164924  0.177790  0.176170
# FLASK                     0.121610        0.023577  0.468529 -0.027419
# PANDAS                   -0.030249        0.070119  0.189492 -0.011089
# SPARK                     0.045133        0.014514  0.439934  0.557793
# NUMPY                    -0.030249        0.070119  0.189492 -0.011089
# PHP                       0.046215       -0.001348  0.145187 -0.021340
# ...

# %% [markdown]
# ------------------------------------
# ------------------------------------

# %% [markdown]
# #  Exploratory Data Analysis (E.D.A.)

# %% [markdown]
# ## 2.1 Job Openings As Per State

# %%
plt.figure(figsize=(13,6), dpi=150)
chart1 = sns.countplot(df["Location"],palette='mako')
plt.title("Job Openings by State",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("State",size=20)
plt.xticks(rotation=80)
chart1.bar_label(chart1.containers[0],size=12)
plt.show()

# %% [markdown]
# ## 2.2 Jobs Available In Each Industry.

# %%
plt.figure(figsize=(13,6), dpi=150)
chart2 = sns.countplot(df["Industry"],palette='twilight')
plt.title("Job Openings by Industry",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Industry",size=20)
plt.xticks(rotation=30,fontsize=12)
chart2.bar_label(chart2.containers[0],size=12)
plt.show()

# %% [markdown]
# ## 2.3 Jobs Available In  Company As Per Employee Count

# %%
plt.figure(figsize=(13,6), dpi=150)
chart3 = sns.countplot(df["Company_Name"],hue=df["Employee_count"],palette='Blues_r')
# plt.title("Job Openings by Company",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Company",size=20)
plt.xticks(rotation=70)
chart3.bar_label(chart3.containers[3],size=13)
plt.show()

# %% [markdown]
# ## 2.4 Job Openings At Each Level

# %%
plt.figure(figsize=(13,6), dpi=200)
chart=sns.countplot(df["Level"],palette='ocean')
plt.title("Job Openings at different levels",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Level",size=20)
chart.bar_label(chart.containers[0],size=13)
plt.show()

# %% [markdown]
# ## 2.5  Job Openings For Different Involvement Nature

# %%
plt.figure(figsize=(13,6), dpi=200)
chart = sns.countplot(df["Involvement"],palette='ocean_r')
plt.title("Job Openings for different involvement natures",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Involvement nature",size=20)
chart.bar_label(chart.containers[0],size=13)
plt.show()

# %% [markdown]
# ## 2.6 Checking Relation Between Linkedin Follower And Employee Count

# %%
plt.figure(figsize=(20,10),dpi=100)
chart = sns.scatterplot(data=df,x="LinkedIn_Followers",y="Employee_count",hue="Company_Name",s=400,palette='Dark2')
plt.title("Relation between linkedin follower & employee count for each company",size=25)
plt.ylabel("Employee Count",size=22)
plt.xlabel("Followers",size=22)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
chart.bar_label(chart.containers[0],size=13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [75], in <cell line: 8>()
#       6 plt.xticks(fontsize=18)
#       7 plt.yticks(fontsize=18)
# ----> 8 chart.bar_label(chart.containers[0],size=13)
#       9 plt.show()
#
# IndexError: list index out of range

# %% [markdown]
# **Uplers company has an employee count of 5000 and also has a lower number of linkedin followers comapred to other companies.
# TCS has a high employee count as well as largest number of linkedin followers. Eventhough companies like Sutherland, LTIMindtree, Vodafone Idea Limited has a large employee count thier linkedin follower count id even lass than that of Uplers.**

# %% [markdown]
# ## 2.7  Number Of Applications Received By  Companies.

# %%
Application=df[["Company_Name",'LinkedIn_Followers',"Total_applicants"]].groupby(["Company_Name",'LinkedIn_Followers']).sum().reset_index()

# %%
Application
# Out:
#                  Company_Name LinkedIn_Followers  Total_applicants
# 0         ACURA SOLUTIONS LTD              11245               674
# 1       Cactus Communications             531551                72
# 2                     Genpact            2519518               252
# 3    IDESLABS PRIVATE LIMITED              80865              5617
# 4                     Infosys            6790011              1307
# 5                 LTIMindtree             270280              1576
# 6   Tata Consultancy Services           11996967               852
# 7                         UST             783349                22
# 8                      Uplers             793022              4072
# 9       Vodafone Idea Limited             235117               232
# 10                      Wipro            6737300              4328

# %%
plt.figure(figsize=(20,10),dpi=100)
chart = sns.barplot(data=Application,x="Company_Name",y="Total_applicants", palette='ocean')
# plt.title("Total applications received by each Company",size=25)
plt.ylabel("Application count",size=20)
plt.xlabel("Company",size=20)
plt.xticks(rotation=60,size=15)
plt.yticks(size=15)
chart.bar_label(chart.containers[0],size=15)
plt.show()

# %% [markdown]
# ## 2.8 Number of jobs available in each class

# %%
plt.figure(figsize=(20,10),dpi=100)
ax = sns.countplot(df["Class"],palette="viridis")
plt.title("Job Openings by Class",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Class",size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.bar_label(ax.containers[0],size=20)
plt.show()

# %% [markdown]
# ## 2.9 Number of companies in each class

# %%
class_df=df[["Company_Name",'Class']].groupby("Class").nunique().reset_index()
class_df
# Out:
#      Class  Company_Name
# 0  Class 1             3
# 1  Class 2             2
# 2  Class 3             4
# 3  Class 4             2

# %%
plt.figure(figsize=(20,10),dpi=100)
chart = sns.barplot(class_df["Class"],class_df["Company_Name"],palette="vlag")
plt.title("Job Openings by Class",size=25)
plt.ylabel("Number of job openings",size=20)
plt.xlabel("Class",size=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
chart.bar_label(chart.containers[0],size=20)
plt.show()

# %% [markdown]
# ## 2.10  Jobs that require Specific particular skill

# %%
df_skills=df.drop(["Company_Name","Class","Designation","Location","Total_applicants","LinkedIn_Followers","Involvement","Involvement","Level","Employee_count","Industry"],axis=1)
skill_dic={}
for i in df_skills.columns:
    skill_dic[i]=df[i].sum()
data = list(skill_dic.items())
skill_df = pd.DataFrame(data, columns=['Skill', 'Number of jobs requiring the skill'])

# %%
skill_df
# Out:
#          Skill  Number of jobs requiring the skill
# 0       PYTHON                                  76
# 1          C++                                  26
# 2         JAVA                                 167
# 3       HADOOP                                  22
# 4        SCALA                                 140
# 5        FLASK                                  18
# 6       PANDAS                                   3
# 7        SPARK                                  20
# 8        NUMPY                                   3
# 9          PHP                                  11
# 10         SQL                                 192
# 11       MYSQL                                  28
# 12         CSS                                  83
# 13     MONGODB                                  28
# 14        NLTK                                   3
# 15  TENSORFLOW                                   1
# 16       LINUX                                  30
# ...

# %%
plt.figure(figsize=(20,10),dpi=100)
chart = sns.barplot(x=skill_df["Skill"],y=skill_df["Number of jobs requiring the skill"],palette="icefire")
plt.title("Number of jobs that require a particular skill",size=25)
plt.ylabel("Number of jobs",size=22)
plt.xlabel("Skill",size=22)
plt.xticks(fontsize=18,rotation=90)
plt.yticks(fontsize=18)
chart.bar_label(chart.containers[0],size=18)
plt.show()

# %% [markdown]
# ----------------------------------
# ----------------------------------------
# -------------------------------------

# %% [markdown]
# # Thank You
